# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
# and the column containing species information is named 'Feature3'
# and other columns are the features
# The original code assumed the column was named 'species',
# but it seems it is named "Feature3" in your DataFrame.
# Changed 'species' to 'Feature3' in the groupby function.

# Group the DataFrame by the 'Feature3' column
grouped_data = df.groupby('Feature3')

# Calculate the average of each feature for each species
average_features = grouped_data.mean()

# Print the resulting DataFrame with the average features per species
print(average_features)
# Out:
#           Feature1  Feature2
# Feature3
# 2              1.0       5.0
# 3              2.0       4.0
# 4              3.0       3.0
# 5              4.0       2.0
# 6              5.0       1.0
