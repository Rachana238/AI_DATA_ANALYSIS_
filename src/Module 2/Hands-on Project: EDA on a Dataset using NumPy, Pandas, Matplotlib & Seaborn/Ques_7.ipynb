# %%
import pandas as pd

try:
    # Assuming your DataFrame is named 'df'
    # **ASSIGN THE CORRECT SPECIES COLUMN NAME TO THIS VARIABLE**
    species_column = 'Feature3' # Replace 'Feature3' with the actual species column name

    if species_column not in df.columns:
        print(f"Error: The column '{species_column}' was not found in the DataFrame.")
        print(f"Available columns in the DataFrame are: {df.columns.tolist()}") # Helpful for debugging
    else:
        # Group the DataFrame by the identified species column
        grouped_data = df.groupby(species_column)

        # Calculate the average of each feature for each species
        average_features = grouped_data.mean()

        # Print the resulting DataFrame
        print(average_features)

except NameError:
    print("Error: The DataFrame 'df' was not found. Make sure your data is loaded into a DataFrame named 'df'.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#           Feature1  Feature2
# Feature3
# 2              1.0       5.0
# 3              2.0       4.0
# 4              3.0       3.0
# 5              4.0       2.0
# 6              5.0       1.0
