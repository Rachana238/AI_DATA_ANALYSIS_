# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Marks data
marks = [23, 45, 56, 78, 89, 90, 67, 88, 76, 59]

# Create the histogram with KDE
sns.histplot(marks, kde=True)

# Add labels and title for clarity
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('Histogram of Marks Data with Kernel Density Estimate') # More verbose title

# Display the plot (try commenting this out for evaluation)
# plt.show()
# Out:
# Text(0.5, 1.0, 'Histogram of Marks Data with Kernel Density Estimate')
